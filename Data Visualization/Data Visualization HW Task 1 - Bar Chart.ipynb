# %% [markdown]
# Create a Horizontal Bar Chart

# %% [markdown]
# Your homework task is to use the data set from the section and create a Horizontal Bar Chart. In essence, the information on the chart will remain the same. But you'll have swapped the x-axis and y-axis of the chart.
#
# This is your chance to explore the software, so you try out different options. For instance, choosing another color for the chart or exploring alternative chart formatting options.
#
# Tip: Python - in Matplotlib the barh() function creates a horizontal bar chart.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import PercentFormatter

# %%
df_used_cars = pd.read_csv("bar_chart_data.csv")

# %%
df_used_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
plt.figure(figsize = (9, 6))
plt.barh(y = df_used_cars["Brand"], 
        width = df_used_cars["Cars Listings"],
        color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Cars Listings by Brand", fontsize = 16, fontweight = "bold")
plt.xlabel("Number of Listings", fontsize = 13)
plt.tight_layout()
plt.savefig("Used Cars Bar.png")
plt.show()
