# %% [markdown]
# Create a Regression Plot of Auto Insurance in Sweden

# %% [markdown]
# Create a regression plot on the data set of car insurance in Sweden.
#
# Decide which is your x-axis and which is your y-axis.
#
# What is the relationship between the two variables?
#
# How would your interpret the chart?
#
# What would be an appropriate chart title?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import PercentFormatter

# %%
df_auto_insurance = pd.read_csv("regression_auto_insurance_sweden.csv")

# %%
df_auto_insurance
# Out:
#     Claims  Payment
# 0      108    392.5
# 1       19     46.2
# 2       13     15.7
# 3      124    422.2
# 4       40    119.4
# ..     ...      ...
# 58       9     87.4
# 59      31    209.8
# 60      14     95.5
# 61      53    244.6
# 62      26    187.5
#
# [63 rows x 2 columns]

# %%
sns.set(rc = {'figure.figsize': (9, 6)})
sns.regplot(x = "Claims",
            y = "Payment",
            data = df_auto_insurance, 
            scatter_kws = {'color': 'k'},
            line_kws = {'color': 'red'})
plt.xlabel("Claims")
plt.ylabel("Payment")
plt.title("Car Insurance Claims and Payment in Sweden", fontsize = 14, weight = "bold")
plt.show()

# %%
sns.lmplot(x = "Claims", 
           y = "Payment",
           data = df_auto_insurance, 
           height = 10,
           scatter_kws = {'color': 'k'},
           line_kws = {'color': 'red'})
plt.xlabel("Claims")
plt.ylabel("Payment")
plt.title("Car Insurance Claims and Payment in Sweden", fontsize = 14, weight = "bold")
plt.show()
