# %% [markdown]
# Create a Scatter Plot of Student Scores

# %% [markdown]
# Your task is to plot the GPA and SAT student scores using a scatter plot.
#
# Decide which will be your x-axis and y-axis.
#
# Think about chart interpretaion. What is the relationship between these variables?
#
# Consider altering the chart limits, so the y-axis doesn't start from 0.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import PercentFormatter

# %%
df_student_scores = pd.read_csv("student_scores_data.csv")

# %%
df_student_scores
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
plt.figure(figsize = (12, 8))
scatter = plt.scatter(df_student_scores['SAT'],
                      df_student_scores['GPA'],
                      color = "midnightblue")
plt.title("GPA and SAT Student Scores",
          fontsize = 14, 
          weight = "bold")
plt.xlabel("SAT", weight = "bold")
plt.ylabel("GPA", weight = "bold")
plt.show()
